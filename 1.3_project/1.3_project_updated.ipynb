# %%
pip install -r requirements.txt

# %%
pip install chardet
# Out:
# Collecting chardet
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
"""Importing all functions needed for this project."""
import ast
import re

from dateutil.parser import parse

# import chardet
import matplotlib.pyplot as plt
import mysql.connector
import numpy as np
import pandas as pd
import seaborn as sns

from sqlalchemy import (Boolean, BigInteger, Column, create_engine, DateTime, Float, 
                        ForeignKey, Integer, PrimaryKeyConstraint, String, text)
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.schema import CreateTable

from db_config import database, host, password, port, username

from functions_all import (analyze_categorical_column, convert_string_to_list, 
                           detect_encoding, df_to_lowercase, distribution_numerical_cols, 
                           explode_column_to_table, extract_authors, factorize_id, 
                           impute_missing_values, most_common_lang, outlier_cols, 
                           outliers_numerical_cols, remove_brackets_content, 
                           serialize_id, split_and_get_first, standardize_date_format, 
                           winsorize)

# %%
"""These functions do not work properly if they are imported from a different script. 
They still work but do not create Primary and Foreign keys for the tables."""
def mysql_class_from_df_pk(
    df: pd.DataFrame, tablename: str, pk_key: str = "bookId"
) -> type:
    """Create a SQLAlchemy class with a primary key for DataFrame.

    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - tablename (str): Desired table name for the SQLAlchemy class.
    - pk_key (str, optional): Name of the primary key column. Default is "bookId".

    Returns:
    - type: SQLAlchemy ORM class.
    """

    type_mapping = {
        "int64": BigInteger,
        "Int64": BigInteger,
        "float64": Float,
        "object": String(300),
        "string": String(300),
        "bool": Boolean,
        "boolean": Boolean,
        "datetime64[ns]": DateTime,
    }

    attrs = {
        "__tablename__": tablename,
        "__table_args__": {"extend_existing": True},
    }

    for col, dtype in df.dtypes.items():
        if col == pk_key:
            attrs[col] = Column(
                type_mapping[str(dtype)], primary_key=True, autoincrement=True
            )
        else:
            attrs[col] = Column(type_mapping[str(dtype)])

    return type(tablename, (Base,), attrs)

def mysql_class_from_df_fk(
    df: pd.DataFrame, table_name: str, secondary_pk_col: str
) -> type:
    """Dynamically create an ORM class with a primary and foreign keys
    based on a given pandas DataFrame.

    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - table_name (str): Desired table name for the SQLAlchemy class.
    - secondary_pk_col (str): The secondary column name for the composite primary key.

    Returns:
    - type: SQLAlchemy ORM class.
    """

    type_mapping = {
        "int64": BigInteger,
        "Int64": BigInteger,
        "float64": Float,
        "object": String(300),
        "string": String(300),
        "bool": Boolean,
        "boolean": Boolean,
        "datetime64[ns]": DateTime,
    }

    attributes = {
        "__tablename__": table_name,
        "__table_args__": (
            PrimaryKeyConstraint("bookId", secondary_pk_col),
            {"extend_existing": True},
        ),
        "bookId": Column(BigInteger, ForeignKey("books.bookId")),
    }

    for column, dtype in df.dtypes.items():
        if column != "bookId":
            attributes[column] = Column(type_mapping[str(dtype)])

    new_class = type(table_name, (Base,), attributes)
    return new_class

def mysql_class_from_df_fk_single_pk(df: pd.DataFrame, table_name: str) -> type:
    """Dynamically create an ORM class with a foreign key based on a given pandas DataFrame.

    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - table_name (str): Desired table name for the SQLAlchemy class.
    - secondary_pk_col (str): The secondary column name for the composite primary key.

    Returns:
    - type: SQLAlchemy ORM class.
    """

    type_mapping = {
        "int64": BigInteger,
        "Int64": BigInteger,
        "float64": Float,
        "object": String(300),
        "string": String(300),
        "bool": Boolean,
        "boolean": Boolean,
        "datetime64[ns]": DateTime,
    }

    attributes = {
        "__tablename__": table_name,
        "__table_args__": {"extend_existing": True},
        "bookId": Column(BigInteger, ForeignKey("books.bookId")),
    }

    primary_key_name = table_name + "Id"
    attributes[primary_key_name] = Column(BigInteger, primary_key=True, autoincrement=True)

    for column, dtype in df.dtypes.items():
        if column not in [
            "bookId",
            primary_key_name,
        ]:
            attributes[column] = Column(type_mapping[str(dtype)])

    new_class = type(table_name, (Base,), attributes)
    return new_class

# %% [markdown]
# # Identifying file encoding
# Looking for encoding type fails. These blocks are commented out because they
# prevent running the whole script because they break.

# %%
file_path = "books_1.Best_Books_Ever.csv"
encoding = detect_encoding(file_path)
print(f"Detected encoding: {encoding}")

# %%
data2 = pd.read_csv("books_1.Best_Books_Ever.csv", encoding=encoding)
df2 = pd.DataFrame(data2)

# %% [markdown]
# # Loading, EDA and data cleaning

# %%
"""Import and load the data into a dataframe with preferred encoding."""
data = pd.read_csv("books_1.Best_Books_Ever.csv", encoding='utf-8')
df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# 2  The unforgettable novel of a childhood in a sl...  English  9999999999999
# 3  Alternate cover edition of ISBN 9780679783268S...  English  9999999999999
# 4  About three things I was absolutely positive.\...  English  9780316015844
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                           characters  ... firstPublishDate  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...              NaN
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...         06/21/03
# 2  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...         07/11/60
# 3  ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...         01/28/13
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...         10/05/05
#
#                                               awards numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...    6376780
# 1  ['Bram Stoker Award for Works for Young Reader...    2507623
# 2  ['Pulitzer Prize for Fiction (1961)', 'Audie A...    4501075
# 3                                                 []    2998241
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...    4964519
#
#                                       ratingsByStars likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...         96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']         98.0
# 2  ['2363896', '1333153', '573280', '149952', '80...         95.0
# 3  ['1617567', '816659', '373311', '113934', '767...         94.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...         78.0
#
#                                              setting  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1  ['Hogwarts School of Witchcraft and Wizardry (...
# 2               ['Maycomb, Alabama (United States)']
# 3  ['United Kingdom', 'Derbyshire, England (Unite...
# 4  ['Forks, Washington (United States)', 'Phoenix...
#
#                                             coverImg  bbeScore bbeVotes  price
# 0  https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516   5.09
# 1  https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923   7.38
# 2  https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328    NaN
# 3  https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452    NaN
# 4  https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874    2.1
#
# [5 rows x 25 columns]

# %%
df = df_to_lowercase(df)
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52428 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52428 non-null  object
#  1   title             52428 non-null  object
#  2   series            23445 non-null  object
#  3   author            52428 non-null  object
#  4   rating            52428 non-null  float64
#  5   description       51092 non-null  object
#  6   language          48627 non-null  object
#  7   isbn              52428 non-null  object
#  8   genres            52428 non-null  object
#  9   characters        52428 non-null  object
#  10  bookFormat        50955 non-null  object
#  11  edition           4949 non-null   object
#  12  pages             50085 non-null  object
#  13  publisher         48736 non-null  object
#  14  publishDate       51549 non-null  object
#  15  firstPublishDate  31125 non-null  object
#  16  awards            52428 non-null  object
#  17  numRatings        52428 non-null  int64
#  18  ratingsByStars    52428 non-null  object
#  19  likedPercent      51807 non-null  float64
#  20  setting           52428 non-null  object
#  21  coverImg          51823 non-null  object
#  22  bbeScore          52428 non-null  int64
#  23  bbeVotes          52428 non-null  int64
#  24  price             38084 non-null  object
# dtypes: float64(2), int64(3), object(20)
# memory usage: 10.4+ MB

# %%
"""Mapping for column names and types."""
columns_dict = {
                'title': 'string',
                'series': 'string',
                'author': 'string',
                'description': 'string',
                'language': 'string',
                'bookFormat': 'string',
                'edition': 'string',
                'publisher': 'string',
                'coverImg': 'string',
                'language': 'string',
                'bookFormat': 'string',
                'edition': 'string',
                'publisher': 'string',
                'characters': 'string',
                'awards': 'string',
                'author': 'string',
                'setting': 'string',
                'genres': 'string',
                'coverImg': 'string'
                }

for column, dtype in columns_dict.items():
    try:
        df[column] = df[column].astype(dtype)
    except ValueError:
        print(f'Column {column} dtype change failed!')
        
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['pages'] = pd.to_numeric(df['pages'], errors='coerce').astype('Int64')

# %%
df.describe().T
# Out:
#                 count         mean            std   min    25%     50%  \
# rating        52428.0     4.021865       0.367116   0.0   3.82    4.03
# pages         50062.0   328.706664     252.264913   0.0  210.0   304.0
# numRatings    52428.0  17892.59844  103993.201959   0.0  341.0  2309.5
# likedPercent  51807.0    92.231938       5.988683   0.0   90.0    94.0
# bbeScore      52428.0  1985.832475   35169.854432   0.0   84.0    97.0
# bbeVotes      52428.0    22.549535     369.333934  -4.0    1.0     1.0
# price         38072.0     9.657951      24.305323  0.84   3.24     5.2
#
#                  75%        max
# rating          4.23        5.0
# pages          392.0    14777.0
# numRatings    9389.0  7048471.0
# likedPercent    96.0      100.0
# bbeScore       187.0  2993816.0
# bbeVotes         2.0    30516.0
# price         8.8525     898.64

# %%
"""Because bookId is not a good unique identifier I'm looking into combination of title, author, 
descrition and publishDate for a way to identify duplicates."""
"""Check for duplicates based on the 'title', 'author', and 'description' columns."""
potential_duplicates = df[df.duplicated(subset=['title', 'author', 'description'], keep=False)]\
                          .sort_values(by=['title', 'author'])
potential_duplicates[['title', 'author', 'description', 'price']].head(10)

"""Dropping duplicates, sort lets us keep the duplicate with higher price."""
df = df.sort_values(by='price', ascending=False)
df = df.drop_duplicates(subset=['title', 'author', 'description'], keep='first')

# %%
potential_duplicates = df[df.duplicated(subset=['title', 'author', 'isbn'], keep=False)]\
                        .sort_values(by=['isbn', 'title'])
potential_duplicates[['title', 'author', 'isbn']].head(10)
# Out:
#                                           title  \
# 25628                                 wolf hall
# 1296                                  wolf hall
# 23159                                edgedancer
# 27486                                edgedancer
# 23519  john lars zwerenz the complete anthology
# 25539  john lars zwerenz the complete anthology
#
#                                      author           isbn
# 25628      hilary mantel (goodreads author)  9780312429980
# 1296       hilary mantel (goodreads author)  9780312429980
# 23159  brandon sanderson (goodreads author)  9781250166548
# 27486  brandon sanderson (goodreads author)  9781250166548
# 23519                     john lars zwerenz  9999999999999
# 25539                     john lars zwerenz  9999999999999

# %%
df = df.drop_duplicates(subset=['title', 'author', 'isbn'], keep='first')

# %%
"""Check missing values using sns.barplot to visualize missing values in each column"""
plt.figure(figsize=(10, 6))
sns.barplot(x=df.columns, y=df.isnull().sum())
plt.xticks(rotation=90)
plt.xlabel('Columns')
plt.ylabel('Missing Values Count')
plt.title('Missing Values in DataFrame')
plt.show()

# %%
"""Save columns with missing values."""
columns_with_missing_values = df.columns[df.isnull().any()].tolist()
columns_with_missing_values
# Out:
# ['series',
#  'description',
#  'language',
#  'bookFormat',
#  'edition',
#  'pages',
#  'publisher',
#  'publishDate',
#  'firstPublishDate',
#  'likedPercent',
#  'coverImg',
#  'price']

# %%
"""Fixing missing values."""
df['pages'].fillna(df['pages'].median(), inplace=True)
df['likedPercent'].fillna(df['likedPercent'].median(), inplace=True)
df['price'].fillna(df['price'].median(), inplace=True)
df['series'] = df['series'].fillna('unknown')
df['series'] = df['series'].fillna('unknown')
df['language'] = df['language'].fillna('language')
df['description'] = df['description'].fillna('unknown')
df['publisher'] = df['publisher'].fillna('unknown')
df['coverImg'] = df['coverImg'].fillna('unknown')
df['coverImg'] = df['coverImg'].replace("", "unknown")
df['edition'] = df['edition'].fillna('unknown')
df['bookFormat'] = df['bookFormat'].fillna('unknown')

# %%
"""Check for Rows, Nulls and NAs. """
print(df.shape[0], df.isnull().sum().sum(), df.isna().any().sum())
# Out:
# 52418 22177 2

# %%
df.isnull().sum()
# Out:
# bookId                  0
# title                   0
# series                  0
# author                  0
# rating                  0
# description             0
# language                0
# isbn                    0
# genres                  0
# characters              0
# bookFormat              0
# edition                 0
# pages                   0
# publisher               0
# publishDate           879
# firstPublishDate    21298
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent            0
# setting                 0
# coverImg                0
# bbeScore                0
# bbeVotes                0
# price                   0
# dtype: int64

# %%
"""Create analyses dictionary to view for cateogrical columns. """
analysis_results_dict = {}

for column in df.columns:
    try:
        results, shortest, longest = analyze_categorical_column(df, column)
        analysis_results_dict[column] = {
            "analysis_results": results,
            "shortest_value": shortest,
            "longest_value": longest
        }
    except Exception as e:
        print(f"Error occurred for column '{column}': {e}")
# Out:
# Error occurred for column 'rating': Can only use .str accessor with string values!
# Error occurred for column 'pages': Can only use .str accessor with string values!
# Error occurred for column 'numRatings': Can only use .str accessor with string values!
# Error occurred for column 'likedPercent': Can only use .str accessor with string values!
# Error occurred for column 'bbeScore': Can only use .str accessor with string values!
# Error occurred for column 'bbeVotes': Can only use .str accessor with string values!
# Error occurred for column 'price': Can only use .str accessor with string values!

# %%
df['firstPublishDate'] = pd.to_datetime(df['firstPublishDate'].apply(standardize_date_format)\
                          , errors='coerce')
df['publishDate'] = pd.to_datetime(df['publishDate'].apply(standardize_date_format)\
                          , errors='coerce')

df[['firstPublishDate','publishDate']].head(10)
# Out:
#       firstPublishDate publishDate
# 32984       1965-11-06  2007-05-25
# 29560              NaT  1991-10-01
# 51332              NaT  1993-12-01
# 36503              NaT  1994-10-01
# 11517       2012-10-29  2012-10-31
# 18834       2012-01-01  2012-10-20
# 5808        2015-06-28  2015-06-04
# 17663       1933-10-30  1989-03-30
# 19513       2005-09-21  2005-10-05
# 47920       1971-11-06  2007-05-01

# %%
"""Sometimes first publish date is newer than standard publish date, this means data in columns is inaccurate. 
To fix this we merge the columns into one, keeping only the older date, drop the original columns and impute the missing values."""
df['oldestPublishDate'] = df[['firstPublishDate', 'publishDate']].min(axis=1)
df = df.drop(['firstPublishDate', 'publishDate'], axis=1)
df['oldestPublishDate'].fillna(df['oldestPublishDate'].median(), inplace=True)

# %%
"""Fix the bookId column."""
df['bookId'] = df['bookId'].apply(split_and_get_first)
df['bookId'] = df['bookId'].astype(int)

# %%
print(df['bookId'].count() - df['bookId'].nunique())
# Out:
# 0

# %%
analysis_results_dict['title']['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 49872,
#  'total_values': 52418,
#  'duplicated_values': 2546,
#  'values_with_whitespace': 1,
#  'values_with_unusual_chars': 3623,
#  'shortest_value_length': 1,
#  'longest_value_length': 251,
#  'average_value_length': 24.629001488038462}

# %%
analysis_results_dict['title']['shortest_value']
# Out:
#            bookId title   series  \
# 5291      94034.q     q  unknown
# 18158     7100173     т  unknown
# 30187   7737810-z     z  unknown
# 49008    415018.v     v     v #1
# 22869  18339155-f     f  unknown
# 51794  28814866-x     x  unknown
# 19241   4944389-l     l  unknown
# 26071  13423043-z     z  unknown
# 27066  27808997-o     o  unknown
# 29002    49386971     φ  unknown
# 36355   6526307-7     7  unknown
# 41408     4912955     ٧  unknown
#
#                                                   author  rating  \
# 5291   luther blissett, shaun whiteside (translator),...    4.18
# 18158                     victor pelevin, виктор пелевин    3.90
# 30187                                michael thomas ford    3.63
# 49008                                       a.c. crispin    3.88
# 22869                                    daniel kehlmann    3.66
# 51794   ilyasah shabazz, kekla magoon (goodreads author)    3.89
# 19241                                      kristy nelwan    3.92
# 26071             vassilis vassilikos, βασίλης βασιλικός    4.03
# 27066                                      eka kurniawan    4.10
# 29002              γεώργιος φραγκάκης (goodreads author)    4.40
# 36355                                           cem akaş    3.89
# 41408        ghazi a. algosaibi, غازي عبد الرحمن القصيبي    3.84
#
#                                              description  \
# 5291   in 1517, martin luther nails his ninety-five t...
# 18158  «t» — новый роман писателя, в эпоху которого с...
# 30187  the first rule of torching: cleanse with fire....
# 49008  try to resistthey arrived—tens of thousands of...
# 22869  es ist der sommer vor der wirtschaftskrise. ma...
# 51794  winner of the 2016 naacp image award for outst...
# 19241  ava torino, twentysomethinggirl, yang bekerja ...
# 26071  το μυθιστόρημα-ντοκουμέντο για τη δολοφονία το...
# 27066  tentang seekor monyet yang ingin menikah denga...
# 29002  ο φίλιππος βρίσκεται σε κώμα ύστερα από μια απ...
# 36355  "tanrı" mıdır yazar? yoksa, romana sızmış, bal...
# 41408  رواية ساخرة لغازي القصيبيالنيل والفرات:بسخريته...
#
#                     language           isbn  \
# 5291                 english  9780156031967
# 18158                russian  9785699375158
# 30187                english  9780060737580
# 49008                english  9780523422374
# 22869                 german  9783498035440
# 51794               language  9780763690922
# 19241             indonesian  9789790254176
# 26071  greek, modern (1453-)  9789603644613
# 27066             indonesian  9786020325590
# 29002  greek, modern (1453-)  9999999999999
# 36355                turkish  9999999999999
# 41408                 arabic  9999999999999
#
#                                                   genres  \
# 5291   ['historical fiction', 'fiction', 'historical'...
# 18158  ['fiction', 'russia', 'modern', 'contemporary'...
# 30187  ['zombies', 'horror', 'young adult', 'science ...
# 49008  ['science fiction', 'fiction', 'horror', 'fant...
# 22869  ['fiction', 'german literature', 'contemporary...
# 51794  ['historical fiction', 'young adult', 'fiction...
# 19241  ['romance', 'novels', 'fiction', 'chick lit', ...
# 26071  ['fiction', 'greece', 'politics', 'historical ...
# 27066  ['fiction', 'indonesian literature', 'novels',...
# 29002                                                 []
# 36355  ['turkish literature', 'turkish', 'novels', 'f...
# 41408                ['novels', 'fiction', 'unfinished']
#
#                            characters  ...  firstPublishDate  \
# 5291                               []  ...          10/28/99
# 18158  ['граф т.', 'ариэль', 'кнопф']  ...          10/30/09
# 30187                              []  ...               NaN
# 49008                              []  ...              1984
# 22869                              []  ...          10/30/13
# 51794              ['malcolm little']  ...  january 6th 2015
# 19241                  ['ava torino']  ...          10/29/08
# 26071                              []  ...          11/30/66
# 27066                              []  ...               NaN
# 29002                              []  ...               NaN
# 36355                       ['hakan']  ...          11/06/92
# 41408                              []  ...          02/01/98
#
#                                                   awards  numRatings  \
# 5291   ['guardian first book award nominee for longli...        6623
# 18158             ['большая книга for 3rd place (2010)']        1337
# 30187                                                 []         697
# 49008                                                 []        1317
# 22869  ['independent foreign fiction prize nominee (2...        2448
# 51794  ["national book award nominee for young people...        2614
# 19241                                                 []         710
# 26071                                                 []        1005
# 27066  ['kusala sastra khatulistiwa nominee for prosa...        1254
# 29002                                                 []          15
# 36355                                                 []         269
# 41408                                                 []        2017
#
#                               ratingsByStars likedPercent  \
# 5291   ['3131', '2131', '905', '309', '147']         93.0
# 18158      ['464', '439', '307', '91', '36']         91.0
# 30187      ['188', '187', '218', '84', '20']         85.0
# 49008      ['437', '420', '344', '94', '22']         91.0
# 22869     ['474', '994', '708', '225', '47']         89.0
# 51794    ['689', '1126', '652', '113', '34']         94.0
# 19241      ['229', '264', '160', '42', '15']         92.0
# 26071      ['348', '413', '187', '42', '15']         94.0
# 27066       ['420', '595', '194', '39', '6']         96.0
# 29002             ['10', '2', '2', '1', '0']         93.0
# 36355          ['93', '87', '62', '20', '7']         90.0
# 41408     ['648', '684', '463', '154', '68']         89.0
#
#                                                  setting  \
# 5291                                                  []
# 18158                                                 []
# 30187                                                 []
# 49008                                                 []
# 22869                                                 []
# 51794  ['lansing, michigan (united states)', 'boston,...
# 19241                                      ['indonesia']
# 26071                                                 []
# 27066                                                 []
# 29002                                                 []
# 36355                    ['turkey', 'istanbul (turkey)']
# 41408                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 5291   https://i.gr-assets.com/images/s/compressed.ph...       555        7
# 18158  https://i.gr-assets.com/images/s/compressed.ph...       100        1
# 30187  https://i.gr-assets.com/images/s/compressed.ph...        95        1
# 49008  https://i.gr-assets.com/images/s/compressed.ph...        45        1
# 22869  https://i.gr-assets.com/images/s/compressed.ph...        99        1
# 51794  https://i.gr-assets.com/images/s/compressed.ph...        15        1
# 19241  https://i.gr-assets.com/images/s/compressed.ph...       100        1
# 26071  https://i.gr-assets.com/images/s/compressed.ph...        97        1
# 27066  https://i.gr-assets.com/images/s/compressed.ph...        97        1
# 29002  https://i.gr-assets.com/images/s/compressed.ph...        96        1
# 36355  https://i.gr-assets.com/images/s/compressed.ph...        88        1
# 41408  https://i.gr-assets.com/images/s/compressed.ph...        79        1
#
#        price
# 5291   23.63
# 18158  14.93
# 30187   8.07
# 49008   5.40
# 22869   4.35
# 51794   2.91
# 19241   5.20
# 26071   5.20
# 27066   5.20
# 29002   5.20
# 36355   5.20
# 41408   5.20
#
# [12 rows x 25 columns]

# %%
analysis_results_dict['title']['longest_value']
# Out:
#                                         bookId  \
# 21883  12862036-novels-by-robin-hobb-including
#
#                                                    title   series  \
# 21883  novels by robin hobb, including: assassin's ap...  unknown
#
#                  author  rating  \
# 21883  hephaestus books    4.42
#
#                                              description  language  \
# 21883  this book consists entirely of reprints of wik...  language
#
#                 isbn       genres characters  ... firstPublishDate awards  \
# 21883  9781244687097  ['fantasy']         []  ...              NaN     []
#
#        numRatings               ratingsByStars likedPercent setting  \
# 21883          73  ['44', '20', '7', '0', '2']         97.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 21883  https://i.gr-assets.com/images/s/compressed.ph...        99        1
#
#        price
# 21883    5.2
#
# [1 rows x 25 columns]

# %%
non_unique_titles = df[df['title'].duplicated(keep=False)].sort_values(by='title')
non_unique_titles.head(5)
# Out:
#          bookId         title                 series  \
# 385       11590  'salem's lot                unknown
# 3674       5413  'salem's lot                unknown
# 27557   7171787    'til death      secret society #3
# 48062  16000978    'til death         rebel ridge #3
# 11569      7104          1919  the u.s.a. trilogy #2
#
#                                                   author  rating  \
# 385                      stephen king (goodreads author)    4.03
# 3674   stephen king (goodreads author), jerry n. uels...    4.25
# 27557                          miasha (goodreads author)    4.20
# 48062                     sharon sala (goodreads author)    4.23
# 11569       john dos passos, e.l. doctorow (foreword by)    3.99
#
#                                              description language  \
# 385    thousands of miles away from the small townshi...  english
# 3674   stephen king's second novel, the vampire bests...  english
# 27557  celess is back and hotter than ever in miasha'...  english
# 48062  he left in handcuffs. now it's time to set him...  english
# 11569  with 1919, the second volume of his u.s.a. tri...  english
#
#                 isbn                                             genres  \
# 385    9780450031069  ['horror', 'fiction', 'vampires', 'fantasy', '...
# 3674   9780385516488  ['horror', 'fiction', 'vampires', 'fantasy', '...
# 27557  9781416589884                                        ['fiction']
# 48062  9780778314271  ['romantic suspense', 'romance', 'suspense', '...
# 11569  9780618056828  ['fiction', 'classics', 'historical fiction', ...
#
#                                               characters  ...  \
# 385    ['benjamin mears', 'susan norton', 'matt burke...  ...
# 3674                                                  []  ...
# 27557                                                 []  ...
# 48062                      ['lincoln fox', 'meg walker']  ...
# 11569                                                 []  ...
#
#                                                   awards numRatings  \
# 385    ['world fantasy award nominee for best novel (...     334051
# 3674                                                  []      94874
# 27557                                                 []        183
# 48062                                                 []       1008
# 11569                                                 []       2536
#
#                                        ratingsByStars likedPercent  \
# 385    ['122020', '121352', '72184', '14697', '3798']         94.0
# 3674       ['45186', '31994', '14804', '2313', '577']         97.0
# 27557                   ['97', '44', '27', '12', '3']         92.0
# 48062               ['476', '341', '149', '28', '14']         96.0
# 11569             ['840', '1016', '518', '132', '30']         94.0
#
#                                           setting  \
# 385    ["jerusalem's lot, maine (united states)"]
# 3674                                           []
# 27557                                          []
# 48062                ['kentucky (united states)']
# 11569                ['united states of america']
#
#                                                 coverImg bbeScore  bbeVotes  \
# 385    https://i.gr-assets.com/images/s/compressed.ph...    28986       393
# 3674   https://i.gr-assets.com/images/s/compressed.ph...      873        11
# 27557  https://i.gr-assets.com/images/s/compressed.ph...       96         1
# 48062  https://i.gr-assets.com/images/s/compressed.ph...       52         1
# 11569  https://i.gr-assets.com/images/s/compressed.ph...      197         3
#
#        price oldestPublishDate
# 385     1.12        1975-10-17
# 3674   23.39        1975-10-17
# 27557   6.08        2010-08-11
# 48062   6.55        2013-01-01
# 11569   6.96        1932-10-29
#
# [5 rows x 24 columns]

# %%
analysis_results_dict['series']['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 22800,
#  'total_values': 52418,
#  'duplicated_values': 29618,
#  'values_with_whitespace': 58,
#  'values_with_unusual_chars': 868,
#  'shortest_value_length': 1,
#  'longest_value_length': 93,
#  'average_value_length': 12.361917661871876}

# %%
analysis_results_dict['title']['shortest_value']
# Out:
#            bookId title   series  \
# 5291      94034.q     q  unknown
# 18158     7100173     т  unknown
# 30187   7737810-z     z  unknown
# 49008    415018.v     v     v #1
# 22869  18339155-f     f  unknown
# 51794  28814866-x     x  unknown
# 19241   4944389-l     l  unknown
# 26071  13423043-z     z  unknown
# 27066  27808997-o     o  unknown
# 29002    49386971     φ  unknown
# 36355   6526307-7     7  unknown
# 41408     4912955     ٧  unknown
#
#                                                   author  rating  \
# 5291   luther blissett, shaun whiteside (translator),...    4.18
# 18158                     victor pelevin, виктор пелевин    3.90
# 30187                                michael thomas ford    3.63
# 49008                                       a.c. crispin    3.88
# 22869                                    daniel kehlmann    3.66
# 51794   ilyasah shabazz, kekla magoon (goodreads author)    3.89
# 19241                                      kristy nelwan    3.92
# 26071             vassilis vassilikos, βασίλης βασιλικός    4.03
# 27066                                      eka kurniawan    4.10
# 29002              γεώργιος φραγκάκης (goodreads author)    4.40
# 36355                                           cem akaş    3.89
# 41408        ghazi a. algosaibi, غازي عبد الرحمن القصيبي    3.84
#
#                                              description  \
# 5291   in 1517, martin luther nails his ninety-five t...
# 18158  «t» — новый роман писателя, в эпоху которого с...
# 30187  the first rule of torching: cleanse with fire....
# 49008  try to resistthey arrived—tens of thousands of...
# 22869  es ist der sommer vor der wirtschaftskrise. ma...
# 51794  winner of the 2016 naacp image award for outst...
# 19241  ava torino, twentysomethinggirl, yang bekerja ...
# 26071  το μυθιστόρημα-ντοκουμέντο για τη δολοφονία το...
# 27066  tentang seekor monyet yang ingin menikah denga...
# 29002  ο φίλιππος βρίσκεται σε κώμα ύστερα από μια απ...
# 36355  "tanrı" mıdır yazar? yoksa, romana sızmış, bal...
# 41408  رواية ساخرة لغازي القصيبيالنيل والفرات:بسخريته...
#
#                     language           isbn  \
# 5291                 english  9780156031967
# 18158                russian  9785699375158
# 30187                english  9780060737580
# 49008                english  9780523422374
# 22869                 german  9783498035440
# 51794               language  9780763690922
# 19241             indonesian  9789790254176
# 26071  greek, modern (1453-)  9789603644613
# 27066             indonesian  9786020325590
# 29002  greek, modern (1453-)  9999999999999
# 36355                turkish  9999999999999
# 41408                 arabic  9999999999999
#
#                                                   genres  \
# 5291   ['historical fiction', 'fiction', 'historical'...
# 18158  ['fiction', 'russia', 'modern', 'contemporary'...
# 30187  ['zombies', 'horror', 'young adult', 'science ...
# 49008  ['science fiction', 'fiction', 'horror', 'fant...
# 22869  ['fiction', 'german literature', 'contemporary...
# 51794  ['historical fiction', 'young adult', 'fiction...
# 19241  ['romance', 'novels', 'fiction', 'chick lit', ...
# 26071  ['fiction', 'greece', 'politics', 'historical ...
# 27066  ['fiction', 'indonesian literature', 'novels',...
# 29002                                                 []
# 36355  ['turkish literature', 'turkish', 'novels', 'f...
# 41408                ['novels', 'fiction', 'unfinished']
#
#                            characters  ...  firstPublishDate  \
# 5291                               []  ...          10/28/99
# 18158  ['граф т.', 'ариэль', 'кнопф']  ...          10/30/09
# 30187                              []  ...               NaN
# 49008                              []  ...              1984
# 22869                              []  ...          10/30/13
# 51794              ['malcolm little']  ...  january 6th 2015
# 19241                  ['ava torino']  ...          10/29/08
# 26071                              []  ...          11/30/66
# 27066                              []  ...               NaN
# 29002                              []  ...               NaN
# 36355                       ['hakan']  ...          11/06/92
# 41408                              []  ...          02/01/98
#
#                                                   awards  numRatings  \
# 5291   ['guardian first book award nominee for longli...        6623
# 18158             ['большая книга for 3rd place (2010)']        1337
# 30187                                                 []         697
# 49008                                                 []        1317
# 22869  ['independent foreign fiction prize nominee (2...        2448
# 51794  ["national book award nominee for young people...        2614
# 19241                                                 []         710
# 26071                                                 []        1005
# 27066  ['kusala sastra khatulistiwa nominee for prosa...        1254
# 29002                                                 []          15
# 36355                                                 []         269
# 41408                                                 []        2017
#
#                               ratingsByStars likedPercent  \
# 5291   ['3131', '2131', '905', '309', '147']         93.0
# 18158      ['464', '439', '307', '91', '36']         91.0
# 30187      ['188', '187', '218', '84', '20']         85.0
# 49008      ['437', '420', '344', '94', '22']         91.0
# 22869     ['474', '994', '708', '225', '47']         89.0
# 51794    ['689', '1126', '652', '113', '34']         94.0
# 19241      ['229', '264', '160', '42', '15']         92.0
# 26071      ['348', '413', '187', '42', '15']         94.0
# 27066       ['420', '595', '194', '39', '6']         96.0
# 29002             ['10', '2', '2', '1', '0']         93.0
# 36355          ['93', '87', '62', '20', '7']         90.0
# 41408     ['648', '684', '463', '154', '68']         89.0
#
#                                                  setting  \
# 5291                                                  []
# 18158                                                 []
# 30187                                                 []
# 49008                                                 []
# 22869                                                 []
# 51794  ['lansing, michigan (united states)', 'boston,...
# 19241                                      ['indonesia']
# 26071                                                 []
# 27066                                                 []
# 29002                                                 []
# 36355                    ['turkey', 'istanbul (turkey)']
# 41408                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 5291   https://i.gr-assets.com/images/s/compressed.ph...       555        7
# 18158  https://i.gr-assets.com/images/s/compressed.ph...       100        1
# 30187  https://i.gr-assets.com/images/s/compressed.ph...        95        1
# 49008  https://i.gr-assets.com/images/s/compressed.ph...        45        1
# 22869  https://i.gr-assets.com/images/s/compressed.ph...        99        1
# 51794  https://i.gr-assets.com/images/s/compressed.ph...        15        1
# 19241  https://i.gr-assets.com/images/s/compressed.ph...       100        1
# 26071  https://i.gr-assets.com/images/s/compressed.ph...        97        1
# 27066  https://i.gr-assets.com/images/s/compressed.ph...        97        1
# 29002  https://i.gr-assets.com/images/s/compressed.ph...        96        1
# 36355  https://i.gr-assets.com/images/s/compressed.ph...        88        1
# 41408  https://i.gr-assets.com/images/s/compressed.ph...        79        1
#
#        price
# 5291   23.63
# 18158  14.93
# 30187   8.07
# 49008   5.40
# 22869   4.35
# 51794   2.91
# 19241   5.20
# 26071   5.20
# 27066   5.20
# 29002   5.20
# 36355   5.20
# 41408   5.20
#
# [12 rows x 25 columns]

# %%
analysis_results_dict['title']['longest_value']
# Out:
#                                         bookId  \
# 21883  12862036-novels-by-robin-hobb-including
#
#                                                    title   series  \
# 21883  novels by robin hobb, including: assassin's ap...  unknown
#
#                  author  rating  \
# 21883  hephaestus books    4.42
#
#                                              description  language  \
# 21883  this book consists entirely of reprints of wik...  language
#
#                 isbn       genres characters  ... firstPublishDate awards  \
# 21883  9781244687097  ['fantasy']         []  ...              NaN     []
#
#        numRatings               ratingsByStars likedPercent setting  \
# 21883          73  ['44', '20', '7', '0', '2']         97.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 21883  https://i.gr-assets.com/images/s/compressed.ph...        99        1
#
#        price
# 21883    5.2
#
# [1 rows x 25 columns]

# %%
"""Most series make little sense, and contain multiple values after the first separator, 
thus proceeding to keep only the series title."""
df['series'] = df['series'].str.split('#', expand = True)[0]
df['series'] = df['series'].str.strip()

df['series'].head(20)
# Out:
# 32984                           unknown
# 29560                           unknown
# 51332                           unknown
# 36503                           unknown
# 11517          the cat's eye chronicles
# 18834                           unknown
# 5808                   children of time
# 17663                           unknown
# 19513                           unknown
# 47920                           unknown
# 36801                           unknown
# 21689                           unknown
# 37618                           unknown
# 36454    chronicles of ancient darkness
# 17776                           unknown
# 18489                           unknown
# 45177                           unknown
# 46911                           unknown
# 39539                           unknown
# 48821                           unknown
# Name: series, dtype: string

# %%
new_col = 'author'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 28198,
#  'total_values': 52418,
#  'duplicated_values': 24220,
#  'values_with_whitespace': 0,
#  'values_with_unusual_chars': 4225,
#  'shortest_value_length': 2,
#  'longest_value_length': 381,
#  'average_value_length': 30.1103056202068}

# %%
analysis_results_dict[new_col]['shortest_value']
# Out:
#                         bookId                         title   series author  \
# 14844              588066.vice  vice: new and selected poems  unknown     ai
# 30471                 39938003                     天觀雙俠（全四卷）  unknown     鄭丰
# 36880  32156380-passion-heaven                passion heaven  unknown     籽月
#
#        rating                                        description language  \
# 14844    4.12  collected here are poems from ai's previous fi...  english
# 30471    5.00  　　趙觀，從小在青樓成長的他，面貌清秀俊雅，個性卻圓滑狡黠、足智多謀，生父不詳的他在親娘被仇...  chinese
# 36880    3.29  shu ya-wang is a 28 years-old landscape archit...  chinese
#
#                 isbn                                             genres  \
# 14844  9780393320183  ['poetry', 'read for school', 'womens', 'liter...
# 30471  9999999999999                                                 []
# 36880  9999999999999                                                 []
#
#       characters  ... firstPublishDate  \
# 14844         []  ...         03/01/99
# 30471         []  ...              NaN
# 36880         []  ...         11/06/10
#
#                                           awards  numRatings  \
# 14844  ['national book award for poetry (1999)']         480
# 30471                                         []           1
# 36880                                         []           7
#
#                         ratingsByStars likedPercent setting  \
# 14844  ['208', '154', '92', '21', '5']         95.0      []
# 30471                               []         94.0      []
# 36880        ['2', '1', '2', '1', '1']         71.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 14844  https://i.gr-assets.com/images/s/compressed.ph...       169        2
# 30471  https://i.gr-assets.com/images/s/compressed.ph...        95        1
# 36880  https://i.gr-assets.com/images/s/compressed.ph...        88        1
#
#        price
# 14844   5.22
# 30471   5.20
# 36880   5.20
#
# [3 rows x 25 columns]

# %%
analysis_results_dict[new_col]['longest_value']
# Out:
#                     bookId       title                      series  \
# 47020  15980677-kicking-it  kicking it  alex craft #2.5 - ruby red
#
#                                                   author  rating  \
# 47020  faith hunter (goodreads author) (editor), kala...    3.83
#
#                                              description language  \
# 47020  featuring stories by faith hunter * kalayna pr...  english
#
#                 isbn                                             genres  \
# 47020  9780451419002  ['vampires', 'paranormal', 'fantasy', 'antholo...
#
#                                               characters  ...  \
# 47020  ['luc (chicagoland vampires)', 'lindsey (chica...  ...
#
#       firstPublishDate awards  numRatings  \
# 47020              NaN     []        3064
#
#                             ratingsByStars likedPercent setting  \
# 47020  ['823', '1110', '955', '152', '24']         94.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 47020  https://i.gr-assets.com/images/s/compressed.ph...        58        1
#
#        price
# 47020   5.85
#
# [1 rows x 25 columns]

# %%
"""Extract roles using a regex pattern matching, then for each unique author, extract roles 
and append to the all_roles list, add them to a set to keep unique roles list only, exclude 
from that list any author roles and then apply this pattern and role to remove any names 
from authors column that are not authors."""
roles_pattern = re.compile(r'\((.*?)\)')
all_roles = []

for author_str in df['author'].dropna().unique():
    roles_found = roles_pattern.findall(author_str)
    all_roles.extend(roles_found)

unique_roles = list(set(all_roles))

authors_roles = ['author', 'goodreads author']

non_authors = [role for role in unique_roles if role not in authors_roles]

df['author'] = df['author'].apply(extract_authors, args=(non_authors,))

df['author'].head(20)
# Out:
# 32984                                      peter s. beagle
# 29560                                      seth a. klarman
# 51332                                       thomas pynchon
# 36503                                           r.i. davis
# 11517                                       t.l. shreffler
# 18834                                    patrick c. greene
# 5808                                    adrian tchaikovsky
# 17663
# 19513                                    matthew d. heines
# 47920                                       diane di prima
# 36801                                      e.t.a. hoffmann
# 21689                                       janos wimpffen
# 37618                                         eiichiro oda
# 36454                                       michelle paver
# 17776                                  christopher seufert
# 18489    janrae frank, jessica amanda salmonson, lyn mc...
# 45177                                           unica zürn
# 46911                                          neil gaiman
# 39539                  vita sackville-west, virginia woolf
# 48821                                    courtney kirchoff
# Name: author, dtype: object

# %%
len(unique_roles)
# Out:
# 467

# %%
"""Check how many authors should be left in the author column."""
# df['author'][df['author'].str.count(',') == 0].count(), \
#   df['author'][df['author'].str.count(',') == 1].count(), \
#     df['author'][df['author'].str.count(',') == 2].count()
# Out:
# 'Check how many authors should be left in the author column.'

# %%
"""Select only the first 2 authors based on choice above."""
# df['author'] = df['author'].str.split(',').apply(lambda x: ', '.join(x[:2]) if isinstance(x, list) else x)
# Out:
# 'Select only the first 2 authors based on choice above.'

# %%
new_col = 'description'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 50881,
#  'total_values': 52418,
#  'duplicated_values': 1537,
#  'values_with_whitespace': 2348,
#  'values_with_unusual_chars': 25037,
#  'shortest_value_length': 3,
#  'longest_value_length': 24733,
#  'average_value_length': 839.5749742454882}

# %%
analysis_results_dict[new_col]['shortest_value']
# Out:
#                           bookId                title   series  \
# 28866  25657509-train-your-brain     train your brain  unknown
# 28236                    5948950      شيء سيبقى بيننا  unknown
# 43057                   17231104  أحلام الفارس القديم  unknown
# 46255                    5868421       الرسم بالكلمات  unknown
#
#                 author  rating description  language           isbn  \
# 28866  ryuta kawashima    3.84         new   english  9788183224123
# 28236      فاروق جويدة    3.90         شعر    arabic  9999999999999
# 43057  صلاح عبد الصبور    3.65         شعر  language  9999999999999
# 46255       نزار قباني    3.94         شعر    arabic  9999999999999
#
#                                                   genres characters  ...  \
# 28866  ['nonfiction', 'psychology', 'science', 'self ...         []  ...
# 28236          ['poetry', 'literature', 'plays', 'love']         []  ...
# 43057                                         ['poetry']         []  ...
# 46255  ['poetry', 'literature', 'nonfiction', 'love',...         []  ...
#
#       firstPublishDate awards  numRatings  \
# 28866         10/30/03     []         135
# 28236         10/30/83     []        2301
# 43057         11/05/64     []         325
# 46255         11/06/66     []        2839
#
#                             ratingsByStars likedPercent setting  \
# 28866        ['50', '38', '30', '10', '7']         87.0      []
# 28236   ['784', '758', '559', '152', '48']         91.0      []
# 43057       ['73', '113', '99', '33', '7']         88.0      []
# 46255  ['1039', '920', '625', '180', '75']         91.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 28866  https://i.gr-assets.com/images/s/compressed.ph...        96        1
# 28236  https://i.gr-assets.com/images/s/compressed.ph...        96        1
# 43057  https://i.gr-assets.com/images/s/compressed.ph...        75        1
# 46255  https://i.gr-assets.com/images/s/compressed.ph...        62        1
#
#        price
# 28866   3.47
# 28236   5.20
# 43057   5.20
# 46255   5.20
#
# [4 rows x 25 columns]

# %%
analysis_results_dict[new_col]['longest_value']
# Out:
#                                       bookId                         title  \
# 18912                17857619-spiritus-mundi                spiritus mundi
# 22017  17857704-spiritus-mundi---the-romance  spiritus mundi - the romance
#
#                   series                              author  rating  \
# 18912  spiritus mundi #1  robert sheppard (goodreads author)    4.00
# 22017  spiritus mundi #2  robert sheppard (goodreads author)    3.92
#
#                                              description language  \
# 18912  spiritus mundi by robert sheppard, nominated f...  english
# 22017  spiritus mundi by robert sheppard, nominated f...  english
#
#                 isbn genres characters  ... firstPublishDate awards  \
# 18912  9999999999999     []         []  ...              NaN     []
# 22017     b00cgm8bzg     []         []  ...              NaN     []
#
#        numRatings             ratingsByStars likedPercent setting  \
# 18912          14  ['7', '4', '1', '0', '2']         86.0      []
# 22017          13  ['6', '4', '1', '0', '2']         85.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 18912  https://i.gr-assets.com/images/s/compressed.ph...       100        1
# 22017  https://i.gr-assets.com/images/s/compressed.ph...        99        1
#
#        price
# 18912    5.2
# 22017    5.2
#
# [2 rows x 25 columns]

# %%
df['description'] = df['description'].str.strip()

# %%
new_col = 'language'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 82,
#  'total_values': 52418,
#  'duplicated_values': 52336,
#  'values_with_whitespace': 0,
#  'values_with_unusual_chars': 12,
#  'shortest_value_length': 4,
#  'longest_value_length': 37,
#  'average_value_length': 7.121771147315807}

# %%
analysis_results_dict[new_col]['shortest_value'][new_col]
# Out:
# 42242    urdu
# 24234    urdu
# 46040    urdu
# 43603    urdu
# 6036     urdu
#          ...
# 42595    urdu
# 42658    urdu
# 43007    urdu
# 43318    urdu
# 46327    urdu
# Name: language, Length: 63, dtype: string

# %%
analysis_results_dict[new_col]['longest_value'][new_col]
# Out:
# 22126    aromanian; arumanian; macedo-romanian
# 51230    norwegian nynorsk; nynorsk, norwegian
# Name: language, dtype: string

# %%
"""Extract unique languages, rank them by frequency, and apply the most common language 
to each row when multiple languages are present."""
df['language'] = df['language'].str.strip()

languages = df['language'].str.split(';', expand=True).stack().str.strip()
language_ranks = languages.value_counts().index.tolist()

df['language'] = df['language'].apply(most_common_lang, args=(language_ranks,))
df['language'] = df['language'].str.replace(f',', '', regex=True)

df[['bookId', 'language']].tail(10)
# Out:
#          bookId language
# 52440   4565266   polish
# 52450  13501282  english
# 52457  17977864  english
# 52461  22925176  english
# 52462   2613071  persian
# 52467  40510415  english
# 52468  33852466  english
# 52471  12464361  english
# 52473  11492014  english
# 52474  11836711  english

# %%
"""View ranks."""
language_ranks = {lang: language_ranks.index(lang) + 1 for lang in 
                  ["aromanian", "arumanian", "macedo-romanian"] if lang in language_ranks}
language_ranks
# Out:
# {'aromanian': 74, 'arumanian': 75, 'macedo-romanian': 76}

# %%
new_col = 'bookFormat'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 122,
#  'total_values': 52418,
#  'duplicated_values': 52296,
#  'values_with_whitespace': 5,
#  'values_with_unusual_chars': 17,
#  'shortest_value_length': 2,
#  'longest_value_length': 33,
#  'average_value_length': 9.911766950284253}

# %%
analysis_results_dict[new_col]['shortest_value'][new_col]
# Out:
# 36488    文庫
# 26921    文庫
# Name: bookFormat, dtype: string

# %%
analysis_results_dict[new_col]['longest_value'][new_col]
# Out:
# 14071    science fiction book club omnibus
# Name: bookFormat, dtype: string

# %%
"""Clean column, keep only first format from multiple. Not necessarily correct approach, 
could be done same way as with Authors column."""
df['bookFormat'] = df['bookFormat'].str.strip().str.lower()
df['bookFormat'] = df['bookFormat'].str.split(',').str[0]

# %%
"""Creating a list for most commong cases where count exceeds 100. Could be extended 
to include all cases or uze approximate matching. Then map all formats to format mapping, 
and if the case does not match return it as 'unknown' for ease of management of small formats. 
The .get() returns the value for a given key and default value doesn't have a mapping."""
format_mapping = {
    'e-book': 'ebook',
    'electronic book': 'ebook',
    'ebook': 'ebook',
    'pbk.': 'paperback',
    'soft cover': 'paperback',
    'paperback': 'paperback',
    'mass market paperback': 'paperback',
    'trade paper': 'paperback',
    'book': 'hardcover',
    'hardcover': 'hardcover',
    'hard cover': 'hardcover',
    'board book': 'hardcover',
    'kindle edition': 'kindle edition',
    'audiobook': 'audiobook',
    'unknown': 'unknown',
    'other': 'unknown'
}

df['bookFormat'] = df['bookFormat'].apply(lambda x: format_mapping.get(x, 'unknown'))
df['bookFormat'].value_counts()
# Out:
# paperback         29347
# hardcover         12306
# kindle edition     5822
# ebook              2545
# unknown            2291
# audiobook           107
# Name: bookFormat, dtype: int64

# %%
new_col = 'edition'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 1690,
#  'total_values': 52418,
#  'duplicated_values': 50728,
#  'values_with_whitespace': 73,
#  'values_with_unusual_chars': 416,
#  'shortest_value_length': 1,
#  'longest_value_length': 229,
#  'average_value_length': 7.714716318821779}

# %%
analysis_results_dict[new_col]['shortest_value'][new_col]
# Out:
# 52374    1
# 16444    1
# 20483    1
# 20849    1
# 20151    1
#         ..
# 46299    2
# 49160    1
# 49421    1
# 50006    1
# 50402    2
# Name: edition, Length: 202, dtype: string

# %%
analysis_results_dict[new_col]['longest_value'][new_col]
# Out:
# 49270    || 36η έκδοση (ανατύπωση): 2002. νέα, σχολιασμ...
# Name: edition, dtype: string

# %%
df['edition'] = df['edition'].str.strip().str.lower()
df['edition'] = df['edition'].str.split(',', expand = True)[0]

# %%
"""Alternative handling of case similar to Formats, but without forcing all 
non-defined cases into 'unknown'."""
edition_mapping = {
    'first edition': 'first edition',
    '1st edition': 'first edition',
    'first': 'first edition',
    '1st': 'first edition',
    '1': 'first edition',
    'second edition': 'second edition',
    '2nd edition': 'second edition',
    '2nd': 'second edition',
    'large print': 'large print',
    'penguin classics': 'penguin classics',
    'penguin classic': 'penguin classics',
    'oxford world\'s classics': 'oxford world classics',
    'unabridged': 'unabridged',
    'revised edition': 'revised edition',
    'omnibus': 'omnibus',
    'abridged': 'abridged',
    'unknown': 'unknown',
    'other': 'unknown'
}

df['edition'] = df['edition'].map(edition_mapping).fillna(df['edition'])

df['edition'].value_counts()
# Out:
# unknown             47470
# first edition        1503
# second edition        229
# large print           104
# الطبعة الأولى          99
#                     ...
# uncanny x-men           1
# loveswept #426          1
# 1st us                  1
# 127                     1
# norwood editions        1
# Name: edition, Length: 1606, dtype: int64

# %%
new_col = 'publisher'

analysis_results_dict[new_col]['analysis_results']
# Out:
# {'missing_values': 0,
#  'unique_values': 10858,
#  'total_values': 52418,
#  'duplicated_values': 41560,
#  'values_with_whitespace': 0,
#  'values_with_unusual_chars': 2347,
#  'shortest_value_length': 1,
#  'longest_value_length': 105,
#  'average_value_length': 14.742016101339235}

# %%
analysis_results_dict[new_col]['shortest_value'][new_col]
# Out:
# 42894    s
# 37412    q
# Name: publisher, dtype: string

# %%
analysis_results_dict[new_col]['longest_value'][new_col]
# Out:
# 27518    islamic studies scholars
#
# 202 books — 146 vote...
# Name: publisher, dtype: string

# %%
df['publisher'] = df['publisher'].str.strip().str.lower()
df['publisher'] = df['publisher'].str.split(',').str[0]

"""Find publishers that are mentioned more than 100 times, these are then 
used to build a mapping dictionary."""
publisher_counts = df['publisher'].value_counts()
frequent_publishers = publisher_counts[publisher_counts > 100]

frequent_publishers_df = frequent_publishers.reset_index()
frequent_publishers_df.columns = ['Publisher', 'Count']
frequent_publishers_df = frequent_publishers_df.sort_values(by='Publisher')
frequent_publishers_df
# Out:
#                     Publisher  Count
# 24                        ace    195
# 53                    aladdin    128
# 29    amazon digital services    180
# 57                     anchor    113
# 49                atria books    136
# ..                        ...    ...
# 38       w. w. norton company    163
# 50             william morrow    136
# 47  william morrow paperbacks    137
# 61                  zondervan    108
# 46                 دار الشروق    138
#
# [68 rows x 2 columns]

# %%
publisher_mapping = {
    "amazon digital services": "amazon",
    "atria books": "atria",
    "ballantine books": "ballantine",
    "berkley": "berkley",
    "berkley books": "berkley",
    "bethany house publishers": "bethany house",
    "createspace": "createspace independent publishing platform",
    "createspace independent publishing platform": "createspace independent publishing platform",
    "harper": "harpercollins",
    "harper perennial": "harpercollins",
    "harpercollins": "harpercollins",
    "harpercollins publishers": "harpercollins",
    "harperteen": "harperteen",
    "hmh books for young readers": "hmh",
    "little, brown and company": "little brown",
    "little, brown books for young readers": "little brown",
    "penguin": "penguin",
    "penguin books": "penguin",
    "penguin classics": "penguin",
    "penguin group (usa)": "penguin",
    "scholastic": "scholastic inc.",
    "scholastic inc.": "scholastic inc.",
    "scholastic paperbacks": "scholastic inc.",
    "scholastic press": "scholastic inc.",
    "simon & schuster": "simon and schuster",
    "simon pulse": "simon and schuster",
    "simon schuster": "simon and schuster",
    "simon schuster books for young readers": "simon and schuster",
    "st. martin's griffin": "st. martin",
    "st. martin's paperbacks": "st. martin",
    "st. martin's press": "st. martin",
    "william morrow": "william morrow",
    "william morrow paperbacks": "william morrow"
}

df['publisher'] = df['publisher'].map(publisher_mapping).fillna(df['publisher'])

df['publisher'].head(5)
# Out:
# 32984            centro books
# 29560           harpercollins
# 51332               viking pr
# 36503    players press (u.k.)
# 11517         the runaway pen
# Name: publisher, dtype: object

# %%
"""There are multuple formats in ISBN column, though ISBN should be only numbers, 
so ignore any that have anything other than numbers."""
try:
    df['isbn'] = pd.to_numeric(df['isbn'], errors='coerce')
    df['isbn'] = df['isbn'].fillna(9999999999999)
    df['isbn'] = df['isbn'].astype(int)
except Exception as e:
    print(f"Error occurred: {e}")

df['isbn'].head()
# Out:
# 32984    9781933572079
# 29560    9780887305108
# 51332    9780670742240
# 36503    9780887346484
# 11517    9780985166342
# Name: isbn, dtype: int64

# %%
duplicates = df[df.duplicated(subset=['isbn', 'title', 'author', 'edition'], keep=False)]\
              .sort_values(by='isbn')
duplicates['isbn'].count(), duplicates[['isbn', 'title', 'author']].head(6)
# Out:
# (16,
#                  isbn                 title                        author
#  9439   9999999999999  the dark god's bride  dahlia lu, dahlia l. summers
#  9483   9999999999999  the dark god's bride  dahlia lu, dahlia l. summers
#  12004  9999999999999     limits of destiny            sharlyn g. branson
#  12180  9999999999999     limits of destiny            sharlyn g. branson
#  12498  9999999999999     limits of destiny            sharlyn g. branson
#  12781  9999999999999     limits of destiny            sharlyn g. branson)

# %%
df = df.drop_duplicates(subset=['title', 'author', 'description'], keep='first')

# %%
"""Convert column from a string to a list, then create a new column counting 
number of awards. Keep only 5 awards for now."""
df['awards'] = df['awards'].apply(convert_string_to_list)
df['num_awards'] = df['awards'].apply(len)
# df['awards'] = df['awards'].apply(lambda x: x[:5] if isinstance(x, list) else [])
df[['awards', 'num_awards']].head(10)
# Out:
#                                                   awards  num_awards
# 32984                                                 []           0
# 29560                                                 []           0
# 51332                                                 []           0
# 36503                                                 []           0
# 11517                                                 []           0
# 18834                                                 []           0
# 5808   [arthur c. clarke award (2016), grand prix de ...           2
# 17663                                                 []           0
# 19513                                                 []           0
# 47920                                                 []           0

# %%
df['characters'] = df['characters'].apply(convert_string_to_list)
df['num_characters'] = df['characters'].apply(len)
# df['characters'] = df['characters'].apply(lambda x: x[:3] if isinstance(x, list) else [])
df['characters'] = df['characters'].astype(str).apply(remove_brackets_content)
df[['characters', 'num_characters']].tail(10)
# Out:
#                      characters  num_characters
# 52440                        []               0
# 52450  ['giovanni "gio" bravo']               1
# 52457                        []               0
# 52461                        []               0
# 52462                        []               0
# 52467                        []               0
# 52468                        []               0
# 52471                        []               0
# 52473                        []               0
# 52474                        []               0

# %%
"""Also removing duplicate genre's from the setting list."""
df['setting'] = df['setting'].apply(convert_string_to_list)
df['num_setting'] = df['setting'].apply(len)
df['setting'] = df['setting'].apply(lambda x: list(set([setting.lower()\
                  .strip() for setting in x])) if isinstance(x, list) else x)
# df['setting'] = df['setting'].apply(lambda x: x[:5] if isinstance(x, list) else [])
df['setting'] = df['setting'].astype(str).apply(remove_brackets_content)
df[['setting', 'num_setting']].tail(10)
# Out:
#                setting  num_setting
# 52440  ['afghanistan']            1
# 52450               []            0
# 52457               []            0
# 52461               []            0
# 52462               []            0
# 52467               []            0
# 52468               []            0
# 52471               []            0
# 52473               []            0
# 52474               []            0

# %%
df['genres'] = df['genres'].apply(convert_string_to_list)
df['genres'] = df['genres'].apply(lambda x: list(set([genre.lower()\
                .strip() for genre in x])) if isinstance(x, list) else x)
df['num_genres'] = df['genres'].apply(len)
df[['genres', 'num_genres']].head(10)
# Out:
#                                                   genres  num_genres
# 32984  [memoir, biography, biography memoir, nonficti...           7
# 29560  [self help, economics, personal finance, busin...           8
# 51332                                          [fiction]           1
# 36503                                          [fashion]           1
# 11517  [adventure, romance, fantasy, paranormal, fict...          10
# 18834  [fantasy, mystery, paranormal, suspense, ficti...          10
# 5808   [fantasy, science fiction fantasy, space opera...          10
# 17663  [history, writing, nonfiction, language, refer...           7
# 19513                                                 []           0
# 47920               [feminism, poetry, politics, womens]           4

# %%
"""Replace negative values in 'bbeVotes' column with 0."""
df.loc[df['bbeVotes'] < 0, 'bbeVotes'] = 0
df[['bbeScore','rating']][df['bbeScore'] == 0]
# Out:
#        bbeScore  rating
# 52472         0    4.16
# 52475         0    3.70
# 52470         0    4.14
# 52477         0    4.02
# 52476         0    3.85
# 52471         0    4.07
# 52473         0    4.00
# 52474         0    4.19

# %% [markdown]
# # Updating columns, Correlation matrix and Outlier checks

# %%
"""Checking lengths to know how long the VARCHARs have to be for Databse columns."""
categorical_cols = df.select_dtypes(include=['object', 'string']).columns

for column in categorical_cols:
    print(column, df[column].str.len().max())
# Out:
# title 251
# series 90
# author 204
# description 24733
# language 28
# genres 10
# characters 11179
# bookFormat 14
# edition 82
# publisher 105
# awards 41
# ratingsByStars 53
# setting 1602
# coverImg 108

# %%
"""Create normal bookId. It's already unique and there will be no data loss doing this, 
but will allow normal serialization in MySQL database."""
df = df.sort_index()
df['bookId'] = range(1, len(df) + 1)

"""Shortening columns to save space and for computational efficiency."""
# df['title'] = df['title'].str[:50]
# df['series'] = df['series'].str[:30]
df['description'] = df['description'].str[:250]
# df['edition'] = df['edition'].str[:30]
# df['publisher'] = df['publisher'].str[:30]
# df['coverImg'] = df['coverImg'].str[10]

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
categorical_cols = ['title', 'series', 'bookFormat', 'edition', 'publisher']
numerical_cols.remove('bookId')
numerical_cols.remove('isbn')
numerical_cols
# Out:
# ['rating',
#  'pages',
#  'numRatings',
#  'likedPercent',
#  'bbeScore',
#  'bbeVotes',
#  'price',
#  'num_awards',
#  'num_characters',
#  'num_setting',
#  'num_genres']

# %%
desc_stats = df[numerical_cols].describe().T
desc_stats["mode"] = df[numerical_cols].mode().iloc[0]
desc_stats
# Out:
#                   count          mean            std   min    25%     50%  \
# rating          52418.0      4.021828        0.36706   0.0   3.82    4.03
# pages           52418.0    327.563871     246.541716   0.0  217.0   304.0
# numRatings      52418.0  17886.220058  103993.333506   0.0  341.0  2310.5
# likedPercent    52418.0     92.252947       5.955635   0.0   90.0    94.0
# bbeScore        52418.0    1986.11807   35173.199057   0.0   84.0    97.0
# bbeVotes        52418.0     22.554046     369.368931   0.0    1.0     1.0
# price           52418.0      8.437262      20.808974  0.84   3.72     5.2
# num_awards      52418.0      0.429471       1.270468   0.0    0.0     0.0
# num_characters  52418.0      1.400931       6.793336   0.0    0.0     0.0
# num_setting     52418.0      0.330955       1.097274   0.0    0.0     0.0
# num_genres      52418.0      7.770441       3.578112   0.0    6.0    10.0
#
#                     75%        max   mode
# rating             4.23        5.0    4.0
# pages             385.0    14777.0  304.0
# numRatings      9388.25  7048471.0    2.0
# likedPercent       96.0      100.0   94.0
# bbeScore          187.0  2993816.0  100.0
# bbeVotes            2.0    30516.0    1.0
# price              6.57     898.64    5.2
# num_awards          0.0       41.0    0.0
# num_characters      1.0      669.0    0.0
# num_setting         0.0      135.0    0.0
# num_genres         10.0       10.0   10.0

# %%
"""Mapping for column names and types, because some dtypes changed due to manipulations in EDA, 
especially one containing lists."""
columns_dict = {
                'language': 'string',
                'bookFormat': 'string',
                'edition': 'string',
                'publisher': 'string',
                'characters': 'string',
                'awards': 'string',
                'author': 'string',
                'setting': 'string',
                'genres': 'string',
                'bookFormat': 'string',
                'edition': 'string',
                'publisher': 'string',
                'oldestPublishDate': 'datetime64[ns]'
                }

for column, dtype in columns_dict.items():
    try:
        df[column] = df[column].astype(dtype)
    except ValueError:
        print(f'Column {column} dtype change failed!')

# %%
"""
Computing correlation matrix between numerical columns and plotting it 
for ease of visualization. Some columns are highly correlated with one another, 
which makes sense because a votes and ratings are associated.
"""
corr_matrix = df[numerical_cols].corr().round(2)

plt.figure(figsize=(20, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, linewidths=.5)
plt.title("Correlation Matrix")
plt.show()

# %%
""" Plotting categorical Columns, first 10 values only."""
plt.figure(figsize=(15, 5 * len(categorical_cols)))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(len(categorical_cols), 1, i)
    sns.countplot(data=df, y=col, order=df[col].value_counts().index[:10])
    plt.title(f'Distribution of {col}')
    plt.xlabel('Count')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
"""View columns with missing values."""
columns_with_missing_values = df.columns[df.isnull().any()].tolist()
columns_with_missing_values
# Out:
# []

# %%
df.isnull().sum()
# Out:
# bookId               0
# title                0
# series               0
# author               0
# rating               0
# description          0
# language             0
# isbn                 0
# genres               0
# characters           0
# bookFormat           0
# edition              0
# pages                0
# publisher            0
# awards               0
# numRatings           0
# ratingsByStars       0
# likedPercent         0
# setting              0
# coverImg             0
# bbeScore             0
# bbeVotes             0
# price                0
# oldestPublishDate    0
# num_awards           0
# num_characters       0
# num_setting          0
# num_genres           0
# dtype: int64

# %%
# df['coverImg'] = df['coverImg'].replace("", "unknown")
# df['coverImg'] = df['coverImg'].fillna('unknown')

# %%
"""Graphical investigation of numerical columns for outliers."""
outliers_numerical_cols(df)

# %%
"""Create a list with outliers columns."""
outliers_columns = []

numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_columns:
    if outlier_cols(df[col]):
        outliers_columns.append(col)

outliers_columns.remove('isbn')
outliers_columns
# Out:
# ['rating',
#  'pages',
#  'numRatings',
#  'likedPercent',
#  'bbeScore',
#  'bbeVotes',
#  'price',
#  'num_awards',
#  'num_characters',
#  'num_setting']

# %%
df[['numRatings', 'bbeVotes']].head(20)
# Out:
#     numRatings  bbeVotes
# 0      6376780     30516
# 1      2507623     26923
# 2      4501075     23328
# 3      2998241     20452
# 4      4964519     14874
# 5      1834276     14168
# 6      2740713     13264
# 7       517740     12949
# 8       110146     12111
# 9      1074620     11211
# 10     3550714     11287
# 11     1436325     10996
# 12      905731     10594
# 13     1342664     10275
# 14     1933446      9231
# 15     1717312      8993
# 16      966196      9096
# 17      458299      8812
# 18     1624682      8740
# 19      682793      8548

# %%
df[['numRatings', 'bbeVotes']].describe()
# Out:
#          numRatings      bbeVotes
# count  5.241800e+04  52418.000000
# mean   1.788622e+04     22.554046
# std    1.039933e+05    369.368931
# min    0.000000e+00      0.000000
# 25%    3.410000e+02      1.000000
# 50%    2.310500e+03      1.000000
# 75%    9.388250e+03      2.000000
# max    7.048471e+06  30516.000000

# %%
"""Apply winsorization to columns with outliers in order to force extreme values 
into nearest acceptable value."""
for col in outliers_columns:
    df = winsorize(df, col)

# %%
df[['numRatings', 'bbeVotes']].head(20)
# Out:
#     numRatings  bbeVotes
# 0        61420        18
# 1        61420        18
# 2        61420        18
# 3        61420        18
# 4        61420        18
# 5        61420        18
# 6        61420        18
# 7        61420        18
# 8        61420        18
# 9        61420        18
# 10       61420        18
# 11       61420        18
# 12       61420        18
# 13       61420        18
# 14       61420        18
# 15       61420        18
# 16       61420        18
# 17       61420        18
# 18       61420        18
# 19       61420        18

# %%
df[['numRatings', 'bbeVotes']].describe()
# Out:
#          numRatings      bbeVotes
# count  52418.000000  52418.000000
# mean    9307.211759      2.840646
# std    15902.313242      4.207924
# min       11.000000      1.000000
# 25%      341.000000      1.000000
# 50%     2310.500000      1.000000
# 75%     9388.250000      2.000000
# max    61420.000000     18.000000

# %%
df[outliers_columns].describe().T
# Out:
#                   count         mean           std   min     25%      50%  \
# rating          52418.0     4.026894      0.333839   3.0    3.82     4.03
# pages           52418.0   312.013106    139.282717  76.0  217.00   304.00
# numRatings      52418.0  9307.211759  15902.313242  11.0  341.00  2310.50
# likedPercent    52418.0    92.575909      4.571946  82.0   90.00    94.00
# bbeScore        52418.0   225.267217    326.585567  38.0   84.00    97.00
# bbeVotes        52418.0     2.840646      4.207924   1.0    1.00     1.00
# price           52418.0     6.600132      4.732086   2.0    3.72     5.20
# num_awards      52418.0     0.291026      0.619574   0.0    0.00     0.00
# num_characters  52418.0     0.969095      1.987733   0.0    0.00     0.00
# num_setting     52418.0     0.281659      0.569486   0.0    0.00     0.00
#
#                     75%      max
# rating             4.23      5.0
# pages            385.00    629.0
# numRatings      9388.25  61420.0
# likedPercent      96.00     99.0
# bbeScore         187.00   1386.0
# bbeVotes           2.00     18.0
# price              6.57     21.0
# num_awards         0.00      2.0
# num_characters     1.00      7.0
# num_setting        0.00      2.0

# %%
outliers_numerical_cols(df)

# %%
"""View distribution of numerical columns after removal of outliers."""
distribution_numerical_cols(df)

# %% [markdown]
# # Save data to show difference with Winsorization

# %%
file_path = "before_normalization.csv"
df.to_csv(file_path, index=False)

# %%
data = pd.read_csv("before_normalization.csv")
df = pd.DataFrame(data)

# %% [markdown]
# # Normalization

# %%
"""Normalize all remaining columns and split them off into separate tables, 
which will later be used to create MySQL tables and upload data."""
genres_df = explode_column_to_table(df, 'genres', 'genreName')
authors_df = explode_column_to_table(df, 'author', 'authorName')
characters_df = explode_column_to_table(df, 'characters', 'characterName')
settings_df = explode_column_to_table(df, 'setting', 'settingName')
awards_df = explode_column_to_table(df, 'awards', 'awardName')

isbn_df = df[['bookId', 'isbn']].copy()
languages_df = df[['bookId', 'language']].copy()

df = df.drop('isbn', axis=1)
df = df.drop('language', axis=1)

# %%
"""Spliting 'ratingsByStars' column into five separate columns, 
replace missing values with 0 and convert to numeric."""
ratings_columns = ['rating_5_star', 'rating_4_star', 'rating_3_star', 
                   'rating_2_star', 'rating_1_star']
df['ratingsByStars'] = df['ratingsByStars'].apply(convert_string_to_list)
df[ratings_columns] = pd.DataFrame(df['ratingsByStars'].tolist(),\
                        index=df.index).fillna(0).astype(int)
df.drop(columns=['ratingsByStars'], inplace=True)

# %%
ratings_columns = [
    'bookId', 'rating', 'numRatings', 'likedPercent',
    'bbeScore', 'bbeVotes', 'rating_5_star', 'rating_4_star',
    'rating_3_star', 'rating_2_star', 'rating_1_star',
    'num_awards'
]

ratings_df = df[ratings_columns].copy()

ratings_columns.remove('bookId')
df = df.drop(columns=ratings_columns)

"""Compute the 'totalScore' column, 'totalVotes' and 'performanceScore' columns 
that could then be used for ML instead of many other columns individually. 
This is a basic calculation, a more sophisticated method for calculating could be implemented."""
ratings_df['totalScore'] = (
    ratings_df['rating'] * 
    ratings_df['bbeScore'] * 
    ratings_df['likedPercent']
)

ratings_df['totalVotes'] = (
    ratings_df['numRatings'] * 
    ratings_df['bbeVotes']
)

ratings_df['performanceScore'] = ratings_df['totalScore'] / ratings_df['totalVotes']

ratings_df = ratings_df.fillna(0)

ratings_df.head(5)
# Out:
#    bookId  rating  numRatings  likedPercent  bbeScore  bbeVotes  \
# 0       1    4.33     6376780          96.0   2993816     30516
# 1       2    4.50     2507623          98.0   2632233     26923
# 2       3    4.28     4501075          95.0   2269402     23328
# 3       4    4.26     2998241          94.0   1983116     20452
# 4       5    3.60     4964519          78.0   1459448     14874
#
#    rating_5_star  rating_4_star  rating_3_star  rating_2_star  rating_1_star  \
# 0        3444695        1921313         745221         171994          93557
# 1        1593642         637516         222366          39573          14526
# 2        2363896        1333153         573280         149952          80794
# 3        1617567         816659         373311         113934          76770
# 4        1751460        1113682        1008686         542017         548674
#
#    num_awards    totalScore    totalVotes  performanceScore
# 0          41  1.244469e+09  194593818480          0.006395
# 1           9  1.160815e+09   67512734029          0.017194
# 2           4  9.227389e+08  105001077600          0.008788
# 3           0  7.941190e+08   61320024932          0.012950
# 4          25  4.098130e+08   73842255606          0.005550

# %%
books_df = df.copy()

# %%
books_df.columns
# Out:
# Index(['bookId', 'title', 'series', 'description', 'bookFormat', 'edition',
#        'pages', 'publisher', 'coverImg', 'price', 'oldestPublishDate',
#        'num_characters', 'num_setting', 'num_genres'],
#       dtype='object')

# %% [markdown]
# # Uploading data directly to MySQL

# %%
"""Imported connection data used to connect to MySQL without. 
Then creating a database 'books' and renewing engine to include database."""
engine = create_engine(f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/")

with engine.connect() as conn:
    conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {database}"))
conn.close()

engine = create_engine(f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}")
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1266 if not fairy:
# -> 1267     fairy = _ConnectionRecord.checkout(pool)
#    1269     if threadconns is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:208, in MySQLConnection._open_connection(self)
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:137, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     135     self._ssl_active = True
# --> 137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/protocol.py:99, in MySQLProtocol.make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      94 packet = struct.pack('<IIB{filler}{usrlen}sx'.format(
#      95     filler='x' * 23, usrlen=len(username_bytes)),
#      96                      client_flags, max_allowed_packet, charset,
#      97                      username_bytes)
# ---> 99 packet += self._auth_response(client_flags, username, password,
#     100                               database,
#     101                               auth_plugin,
#     102                               auth_data, ssl_enabled)
#     104 packet += self._connect_with_db(client_flags, database)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/protocol.py:58, in MySQLProtocol._auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      57 try:
# ---> 58     auth = get_auth_plugin(auth_plugin)(
#      59         auth_data,
#      60         username=username, password=password, database=database,
#      61         ssl_enabled=ssl_enabled)
#      62     plugin_auth_response = auth.auth_response()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/authentication.py:190, in get_auth_plugin(plugin_name)
#     188         return authclass
# --> 190 raise errors.NotSupportedError(
#     191     "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported
#
# The above exception was the direct cause of the following exception:
#
# NotSupportedError                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 """Imported connection data used to connect to MySQL without.
#       2 Then creating a database 'books' and renewing engine to include database."""
#       3 engine = create_engine(f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/")
# ----> 5 with engine.connect() as conn:
#       6     conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {database}"))
#       7 conn.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3264, in Engine.connect(self)
#    3241 def connect(self) -> Connection:
#    3242     """Return a new :class:`_engine.Connection` object.
#    3243
#    3244     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3261
#    3262     """
# -> 3264     return self._connection_cls(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2426, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2424 elif should_wrap:
#    2425     assert sqlalchemy_exception is not None
# -> 2426     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2427 else:
#    2428     assert exc_info[1] is not None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3266 def raw_connection(self) -> PoolProxiedConnection:
#    3267     """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269     The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287     """
# -> 3288     return self.pool.connect()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1266     if not fairy:
# -> 1267         fairy = _ConnectionRecord.checkout(pool)
#    1269         if threadconns is not None:
#    1270             threadconns.current = weakref.ref(fairy)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/connection.py:137, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     134     self._socket.switch_to_ssl(**ssl_options)
#     135     self._ssl_active = True
# --> 137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
#     144 self._auth_switch_request(username, password)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/protocol.py:99, in MySQLProtocol.make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      93     username_bytes = username
#      94 packet = struct.pack('<IIB{filler}{usrlen}sx'.format(
#      95     filler='x' * 23, usrlen=len(username_bytes)),
#      96                      client_flags, max_allowed_packet, charset,
#      97                      username_bytes)
# ---> 99 packet += self._auth_response(client_flags, username, password,
#     100                               database,
#     101                               auth_plugin,
#     102                               auth_data, ssl_enabled)
#     104 packet += self._connect_with_db(client_flags, database)
#     106 if client_flags & ClientFlag.PLUGIN_AUTH:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/protocol.py:58, in MySQLProtocol._auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      55     return b'\x00'
#      57 try:
# ---> 58     auth = get_auth_plugin(auth_plugin)(
#      59         auth_data,
#      60         username=username, password=password, database=database,
#      61         ssl_enabled=ssl_enabled)
#      62     plugin_auth_response = auth.auth_response()
#      63 except (TypeError, errors.InterfaceError) as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/authentication.py:190, in get_auth_plugin(plugin_name)
#     187     if authclass.plugin_name == plugin_name:
#     188         return authclass
# --> 190 raise errors.NotSupportedError(
#     191     "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: (mysql.connector.errors.NotSupportedError) Authentication plugin 'caching_sha2_password' is not supported
# (Background on this error at: https://sqlalche.me/e/20/tw8g)

# %%
"""Create SQLAlchemy classes with functions defined in functions_all.py."""
Base = declarative_base()
Book = mysql_class_from_df_pk(books_df, 'books', 'bookId')

# %%
"""Check what 'create_all' would create in the 'books' table"""
print(CreateTable(Book.__table__).compile(engine))

# %%
"""Create other database tables definitions, which include Primary and Foreign Keys."""
# Ratings = mysql_class_from_df_fk(ratings_df, 'ratings', 'performanceScore')
Ratings = mysql_class_from_df_fk_single_pk(ratings_df, 'ratings')
Genres = mysql_class_from_df_fk(genres_df, 'genres', 'genreName')
Author = mysql_class_from_df_fk(authors_df, 'authors', 'authorName')
Characters = mysql_class_from_df_fk(characters_df, 'characters', 'characterName')
Settings = mysql_class_from_df_fk(settings_df, 'settings', 'settingName')
Awards = mysql_class_from_df_fk(awards_df, 'awards', 'awardName')
Isbn = mysql_class_from_df_fk(isbn_df, 'isbn', 'isbn')
Languages = mysql_class_from_df_fk(languages_df, 'languages', 'language')

# %%
"""Create all tables in MySQL database."""
Base.metadata.create_all(engine)

# %%
"""Create the dfs_list that contains all dataframes, then table_names list that contain respective table names in MySQL database."""
dfs_list = [
    books_df, ratings_df, genres_df, authors_df,
    characters_df, settings_df, awards_df, isbn_df,
    languages_df
]

table_names = ['books', 'ratings', 'genres', 'authors', 'characters', 'settings', 'awards', 'isbn', 'languages']

# %%
"""Fixing infinity values that resulted from multiplication without removing outliers."""
cols_with_inf = ratings_df.columns[(ratings_df == np.inf).any()]
for col in cols_with_inf:
    percentile_99 = ratings_df[col].quantile(0.99)
    ratings_df[col].replace(np.inf, percentile_99, inplace=True)

# %%
"""Upload all the data from the dataframes to MySQL database tables."""
for df, table_name in zip(dfs_list, table_names):
    df.to_sql(
        name=table_name,
        con=engine,
        if_exists='append',
        index=False
    )
    
print("Upload complete.")
# Out:
# Upload complete.

# %%
Base.metadata.clear()

# %%
"""Creating a view in MySQL."""
create_view_query = """
CREATE OR REPLACE VIEW books_authors_view AS
SELECT 
    b.*,
    a.authorName
FROM books AS b
LEFT JOIN authors AS a ON b.bookId = a.bookId;
"""

with engine.connect() as connection:
    connection.execute(text(create_view_query))

# %%
"""Creating an all tables view in MySQL."""
create_view_query = """
CREATE OR REPLACE VIEW all_tables AS
SELECT 
    b.*,
    r.totalScore,
    r.totalVotes,
    r.performanceScore,
    g.genreName,
    a.authorName,
    c.characterName,
    s.settingName,
    aw.awardName,
    i.isbn,
    l.language
FROM books AS b
LEFT JOIN ratings AS r ON b.bookId = r.bookId
LEFT JOIN genres AS g ON b.bookId = g.bookId
LEFT JOIN authors AS a ON b.bookId = a.bookId
LEFT JOIN characters AS c ON b.bookId = c.bookId
LEFT JOIN settings AS s ON b.bookId = s.bookId
LEFT JOIN awards AS aw ON b.bookId = aw.bookId
LEFT JOIN isbn AS i ON b.bookId = i.bookId
LEFT JOIN languages AS l ON b.bookId = l.bookId;

"""

with engine.connect() as connection:
    connection.execute(text(create_view_query))

# %%
"""Creating a Most popular books view in MySQL."""
create_view_query = """
CREATE OR REPLACE VIEW most_popular_books AS
SELECT 
b.*,
r.totalScore,
r.totalVotes,
r.performanceScore
FROM books AS b
LEFT JOIN ratings AS r ON b.bookId = r.bookId
ORDER BY totalScore DESC;
"""

with engine.connect() as connection:
    connection.execute(text(create_view_query))

# %%
"""Import the view back into pandas DataFrame"""
select_query = """SELECT * FROM books_authors_view"""
df_books_with_authors = pd.read_sql(select_query, engine)
df_books_with_authors.head(5)
# Out:
#    bookId                                      title                 series  \
# 0       1                           the hunger games       the hunger games
# 1       2  harry potter and the order of the phoenix           harry potter
# 2       3                      to kill a mockingbird  to kill a mockingbird
# 3       4                        pride and prejudice                unknown
# 4       5                                   twilight      the twilight saga
#
#                                          description bookFormat  \
# 0  winning means fame and fortune.losing means ce...  hardcover
# 1  there is a door at the end of a silent corrido...  paperback
# 2  the unforgettable novel of a childhood in a sl...  paperback
# 3  alternate cover edition of isbn 9780679783268s...  paperback
# 4  about three things i was absolutely positive.\...  paperback
#
#                    edition  pages                         publisher  \
# 0            first edition    374                   scholastic inc.
# 1               us edition    870                   scholastic inc.
# 2                  unknown    324  harper perennial modern classics
# 3  modern library classics    279                    modern library
# 4                  unknown    501                            little
#
#                                             coverImg  price oldestPublishDate  \
# 0  https://i.gr-assets.com/images/s/compressed.ph...   5.09        2008-09-14
# 1  https://i.gr-assets.com/images/s/compressed.ph...   7.38        2003-06-21
# 2  https://i.gr-assets.com/images/s/compressed.ph...   5.20        1960-07-11
# 3  https://i.gr-assets.com/images/s/compressed.ph...   5.20        2000-10-10
# 4  https://i.gr-assets.com/images/s/compressed.ph...   2.10        2005-10-05
#
#    num_characters  num_setting  num_genres       authorName
# 0              23            3          10  suzanne collins
# 1              44            2          10       jk rowling
# 2              14            1          10       harper lee
# 3              24            4          10      jane austen
# 4              17            3          10  stephenie meyer

# %%
select_query = """
SELECT DISTINCT(settingName)
FROM all_tables
WHERE bookId = 2
"""

df_bookId_2 = pd.read_sql(select_query, engine)
df_bookId_2
# Out:
#                                   settingName
# 0                                     england
# 1  hogwarts school of witchcraft and wizardry
# 2                                      london

# %%
"""Top10 books by performanceScore"""
select_query = """
SELECT *
FROM most_popular_books
ORDER BY totalVotes DESC
LIMIT 10;
"""

df_top10 = pd.read_sql(select_query, engine)
df_top10
# Out:
#    bookId                                      title                 series  \
# 0       1                           the hunger games       the hunger games
# 1       3                      to kill a mockingbird  to kill a mockingbird
# 2       5                                   twilight      the twilight saga
# 3       2  harry potter and the order of the phoenix           harry potter
# 4       4                        pride and prejudice                unknown
# 5      33      harry potter and the sorcerer's stone           harry potter
# 6      11                     the fault in our stars                unknown
# 7       7                                animal farm                unknown
# 8      28                           the great gatsby                unknown
# 9       6                             the book thief                unknown
#
#                                          description bookFormat  \
# 0  winning means fame and fortune.losing means ce...  hardcover
# 1  the unforgettable novel of a childhood in a sl...  paperback
# 2  about three things i was absolutely positive.\...  paperback
# 3  there is a door at the end of a silent corrido...  paperback
# 4  alternate cover edition of isbn 9780679783268s...  paperback
# 5  harry potter's life is miserable. his parents ...  hardcover
# 6  despite the tumor-shrinking medical miracle th...  hardcover
# 7  librarian's note: there is an alternate cover ...  paperback
# 8  alternate cover edition isbn: 0743273567 (isbn...  paperback
# 9  librarian's note: an alternate cover edition c...  hardcover
#
#                    edition  pages                         publisher  \
# 0            first edition    374                   scholastic inc.
# 1                  unknown    324  harper perennial modern classics
# 2                  unknown    501                            little
# 3               us edition    870                   scholastic inc.
# 4  modern library classics    279                    modern library
# 5          library edition    309                    scholastic inc
# 6                  unknown    313                      dutton books
# 7                  unknown    141                   signet classics
# 8                 us / can    200                          scribner
# 9   first american edition    552                   alfred a. knopf
#
#                                             coverImg  price oldestPublishDate  \
# 0  https://i.gr-assets.com/images/s/compressed.ph...   5.09        2008-09-14
# 1  https://i.gr-assets.com/images/s/compressed.ph...   5.20        1960-07-11
# 2  https://i.gr-assets.com/images/s/compressed.ph...   2.10        2005-10-05
# 3  https://i.gr-assets.com/images/s/compressed.ph...   7.38        2003-06-21
# 4  https://i.gr-assets.com/images/s/compressed.ph...   5.20        2000-10-10
# 5  https://i.gr-assets.com/images/s/compressed.ph...   5.20        1997-06-26
# 6  https://i.gr-assets.com/images/s/compressed.ph...   5.20        2012-01-10
# 7  https://i.gr-assets.com/images/s/compressed.ph...   4.42        1945-08-17
# 8  https://i.gr-assets.com/images/s/compressed.ph...   5.20        1925-04-10
# 9  https://i.gr-assets.com/images/s/compressed.ph...   3.80        2005-09-01
#
#    num_characters  num_setting  num_genres    totalScore    totalVotes  \
# 0              23            3          10  1.244470e+09  194593818480
# 1              14            1          10  9.227390e+08  105001077600
# 2              17            3          10  4.098130e+08   73842255606
# 3              44            2          10  1.160810e+09   67512734029
# 4              24            4          10  7.941190e+08   61320024932
# 5              32            3          10  2.967060e+08   51792164908
# 6               3            2          10  4.256150e+08   40076908918
# 7              10            2          10  4.588740e+08   36352817232
# 8               8            3          10  2.663900e+08   30740153568
# 9               8            2          10  5.759210e+08   25988022368
#
#    performanceScore
# 0          0.006395
# 1          0.008788
# 2          0.005550
# 3          0.017194
# 4          0.012950
# 5          0.005729
# 6          0.010620
# 7          0.012623
# 8          0.008666
# 9          0.022161

# %%
"""Creating a requirements file."""
pip freeze > requirements.txt
# Out:
#   Cell In[107], line 2
#     pip freeze > requirements.txt
#         ^
# SyntaxError: invalid syntax
